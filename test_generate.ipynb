# %%
import pandas as pd
import numpy as np
shop_info=pd.read_csv('C:\\Users\\fcn\\Desktop\\dataset\\dataset\\shop_info.txt',names=['商家id','市名','所在位置编号','人均消费','评分','评论数','门店等级','一级品类名称','二级分类名称','三级分类名称'])
shop_info
# Out:
#       商家id   市名  所在位置编号  人均消费   评分   评论数  门店等级 一级品类名称       二级分类名称   三级分类名称
# 0        1   湖州     885     8  4.0  12.0     2     美食         休闲茶饮    饮品/甜点
# 1        2  哈尔滨      64    19  NaN   NaN     1  超市便利店           超市      NaN
# 2        3   南昌     774     5  3.0   2.0     0     美食         休闲茶饮       奶茶
# 3        4   天津     380    18  NaN   NaN     1  超市便利店           超市      NaN
# 4        5   杭州     263     2  2.0   2.0     0     美食         休闲食品     生鲜水果
# 5        6   大连    1139    13  3.0   1.0     0     美食         烘焙糕点       面包
# 6        7   绍兴     145    13  3.0   9.0     2     美食           快餐     西式快餐
# 7        8   杭州     234    16  3.0   1.0     0     美食         休闲食品     生鲜水果
# 8        9   杭州    1120    15  4.0   0.0     1  超市便利店           超市      NaN
# 9       10   孝感      98    10  NaN   NaN     0  超市便利店           超市      NaN
# 10      11   上海     134    12  3.0   1.0     0     美食           小吃     其它小吃
# ...

# %%
test=pd.DataFrame(shop_info,columns=['商家id','市名','所在位置编号','人均消费','评分','评论数','门店等级','一级品类名称','二级分类名称','三级分类名称','2016-11-01','2016-11-02','2016-11-03','2016-11-04','2016-11-05','2016-11-06','2016-11-07','2016-11-08','2016-11-09','2016-11-10','2016-11-11','2016-11-12','2016-11-13','2016-11-14'])
test
# Out:
#       商家id   市名  所在位置编号  人均消费   评分   评论数  门店等级 一级品类名称       二级分类名称   三级分类名称  \
# 0        1   湖州     885     8  4.0  12.0     2     美食         休闲茶饮    饮品/甜点
# 1        2  哈尔滨      64    19  NaN   NaN     1  超市便利店           超市      NaN
# 2        3   南昌     774     5  3.0   2.0     0     美食         休闲茶饮       奶茶
# 3        4   天津     380    18  NaN   NaN     1  超市便利店           超市      NaN
# 4        5   杭州     263     2  2.0   2.0     0     美食         休闲食品     生鲜水果
# 5        6   大连    1139    13  3.0   1.0     0     美食         烘焙糕点       面包
# 6        7   绍兴     145    13  3.0   9.0     2     美食           快餐     西式快餐
# 7        8   杭州     234    16  3.0   1.0     0     美食         休闲食品     生鲜水果
# 8        9   杭州    1120    15  4.0   0.0     1  超市便利店           超市      NaN
# 9       10   孝感      98    10  NaN   NaN     0  超市便利店           超市      NaN
# 10      11   上海     134    12  3.0   1.0     0     美食           小吃     其它小吃
# ...

# %%
test.columns
# Out:
# Index(['商家id', '市名', '所在位置编号', '人均消费', '评分', '评论数', '门店等级', '一级品类名称', '二级分类名称',
#        '三级分类名称', '2016-11-01', '2016-11-02', '2016-11-03', '2016-11-04',
#        '2016-11-05', '2016-11-06', '2016-11-07', '2016-11-08', '2016-11-09',
#        '2016-11-10', '2016-11-11', '2016-11-12', '2016-11-13', '2016-11-14'],
#       dtype='object')

# %%
test.drop(['市名','所在位置编号','人均消费','评分','评论数','门店等级','一级品类名称','二级分类名称','三级分类名称'],axis=1,inplace=True)
test
# Out:
#       商家id  2016-11-01  2016-11-02  2016-11-03  2016-11-04  2016-11-05  \
# 0        1         NaN         NaN         NaN         NaN         NaN
# 1        2         NaN         NaN         NaN         NaN         NaN
# 2        3         NaN         NaN         NaN         NaN         NaN
# 3        4         NaN         NaN         NaN         NaN         NaN
# 4        5         NaN         NaN         NaN         NaN         NaN
# 5        6         NaN         NaN         NaN         NaN         NaN
# 6        7         NaN         NaN         NaN         NaN         NaN
# 7        8         NaN         NaN         NaN         NaN         NaN
# 8        9         NaN         NaN         NaN         NaN         NaN
# 9       10         NaN         NaN         NaN         NaN         NaN
# 10      11         NaN         NaN         NaN         NaN         NaN
# 11      12         NaN         NaN         NaN         NaN         NaN
# ...

# %%
test=test.set_index('商家id')
test=test.stack(dropna=False)
test=test.reset_index()
test
# Out:
#        商家id     level_1   0
# 0         1  2016-11-01 NaN
# 1         1  2016-11-02 NaN
# 2         1  2016-11-03 NaN
# 3         1  2016-11-04 NaN
# 4         1  2016-11-05 NaN
# 5         1  2016-11-06 NaN
# 6         1  2016-11-07 NaN
# 7         1  2016-11-08 NaN
# 8         1  2016-11-09 NaN
# 9         1  2016-11-10 NaN
# 10        1  2016-11-11 NaN
# 11        1  2016-11-12 NaN
# 12        1  2016-11-13 NaN
# 13        1  2016-11-14 NaN
# 14        2  2016-11-01 NaN
# 15        2  2016-11-02 NaN
# 16        2  2016-11-03 NaN
# 17        2  2016-11-04 NaN
# 18        2  2016-11-05 NaN
# 19        2  2016-11-06 NaN
# 20        2  2016-11-07 NaN
# 21        2  2016-11-08 NaN
# 22        2  2016-11-09 NaN
# 23        2  2016-11-10 NaN
# 24        2  2016-11-11 NaN
# 25        2  2016-11-12 NaN
# 26        2  2016-11-13 NaN
# 27        2  2016-11-14 NaN
# 28        3  2016-11-01 NaN
# 29        3  2016-11-02 NaN
# ...     ...         ...  ..
# 27970  1998  2016-11-13 NaN
# ...

# %%
test=test.rename(columns={'level_1':'支付时间',0:'客户流量'})
test
# Out:
#        商家id        支付时间  客户流量
# 0         1  2016-11-01   NaN
# 1         1  2016-11-02   NaN
# 2         1  2016-11-03   NaN
# 3         1  2016-11-04   NaN
# 4         1  2016-11-05   NaN
# 5         1  2016-11-06   NaN
# 6         1  2016-11-07   NaN
# 7         1  2016-11-08   NaN
# 8         1  2016-11-09   NaN
# 9         1  2016-11-10   NaN
# 10        1  2016-11-11   NaN
# 11        1  2016-11-12   NaN
# 12        1  2016-11-13   NaN
# 13        1  2016-11-14   NaN
# 14        2  2016-11-01   NaN
# 15        2  2016-11-02   NaN
# 16        2  2016-11-03   NaN
# 17        2  2016-11-04   NaN
# 18        2  2016-11-05   NaN
# 19        2  2016-11-06   NaN
# 20        2  2016-11-07   NaN
# 21        2  2016-11-08   NaN
# 22        2  2016-11-09   NaN
# 23        2  2016-11-10   NaN
# 24        2  2016-11-11   NaN
# 25        2  2016-11-12   NaN
# 26        2  2016-11-13   NaN
# 27        2  2016-11-14   NaN
# 28        3  2016-11-01   NaN
# 29        3  2016-11-02   NaN
# ...

# %%
test=shop_info.merge(test,on='商家id',copy=False)
test
# Out:
#        商家id   市名  所在位置编号  人均消费   评分   评论数  门店等级 一级品类名称 二级分类名称 三级分类名称  \
# 0         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 1         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 2         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 3         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 4         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 5         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 6         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 7         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 8         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 9         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 10        1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 11        1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 12        1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# ...

# %%
import datetime
from datetime import date
test['支付时间']=test['支付时间'].apply(pd.to_datetime)
test['星期']=test['支付时间'].apply(date.isoweekday)
test
# Out:
#        商家id   市名  所在位置编号  人均消费   评分   评论数  门店等级 一级品类名称 二级分类名称 三级分类名称  \
# 0         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 1         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 2         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 3         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 4         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 5         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 6         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 7         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 8         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 9         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 10        1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 11        1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 12        1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# ...

# %%
test['前1天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=1))
test['前2天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=2))
test['前3天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=3))
test['前4天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=4))
test['前5天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=5))
test['前6天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=6))
test['前7天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=7))
test['前8天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=8))
test['前9天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=9))
test['前10天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=10))
test['前11天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=11))
test['前12天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=12))
test['前13天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=13))
test['前14天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=14))
test['前15天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=15))
test['前16天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=16))
test['前17天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=17))
test['前18天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=18))
test['前19天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=19))
test['前20天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=20))
test['前21天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=21))
test['前22天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=22))
test['前23天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=23))
test['前24天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=24))
test['前25天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=25))
test['前26天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=26))
test['前27天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=27))
test['前28天']=test['支付时间'].apply(lambda x:x- datetime.timedelta(days=28))
test.to_csv('C:\\Users\\fcn\\Desktop\\dataset\\dataset\\test.txt')
