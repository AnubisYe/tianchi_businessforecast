# %%
import pandas as pd
import numpy as np
train=pd.read_csv('C:\\Users\\fcn\\Desktop\\dataset\\dataset\\train.txt',encoding='gbk')
train.drop(['Unnamed: 0'],axis=1,inplace=True)
train
# Out:
#         商家id        支付时间  客户流量  市名  所在位置编号  人均消费   评分   评论数  门店等级 一级品类名称  \
# 0          1  2015-10-10   188  湖州     885     8  4.0  12.0     2     美食
# 1          1  2015-10-11   272  湖州     885     8  4.0  12.0     2     美食
# 2          1  2015-10-12   257  湖州     885     8  4.0  12.0     2     美食
# 3          1  2015-10-13   239  湖州     885     8  4.0  12.0     2     美食
# 4          1  2015-10-14   277  湖州     885     8  4.0  12.0     2     美食
# 5          1  2015-10-15   227  湖州     885     8  4.0  12.0     2     美食
# 6          1  2015-10-16   242  湖州     885     8  4.0  12.0     2     美食
# 7          1  2015-10-17   293  湖州     885     8  4.0  12.0     2     美食
# 8          1  2015-10-18   291  湖州     885     8  4.0  12.0     2     美食
# 9          1  2015-10-19   256  湖州     885     8  4.0  12.0     2     美食
# 10         1  2015-10-20   262  湖州     885     8  4.0  12.0     2     美食
# 11         1  2015-10-21   271  湖州     885     8  4.0  12.0     2     美食
# ...

# %%
test=pd.read_csv('C:\\Users\\fcn\\Desktop\\dataset\\dataset\\test.txt',encoding='gbk')
test.drop(['Unnamed: 0'],axis=1,inplace=True)
test
# Out:
#        商家id   市名  所在位置编号  人均消费   评分   评论数  门店等级 一级品类名称 二级分类名称 三级分类名称  \
# 0         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 1         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 2         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 3         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 4         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 5         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 6         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 7         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 8         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 9         1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 10        1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 11        1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# 12        1   湖州     885     8  4.0  12.0     2     美食   休闲茶饮  饮品/甜点
# ...

# %%
#train.dropna(thresh=30,inplace=True)
train.loc[train['前1天客户流量'].isnull(),'前1天客户流量']=train.loc[train['前1天客户流量'].isnull(),'客户流量']
train.loc[train['前2天客户流量'].isnull(),'前2天客户流量']=train.loc[train['前2天客户流量'].isnull(),'客户流量']
train.loc[train['前3天客户流量'].isnull(),'前3天客户流量']=train.loc[train['前3天客户流量'].isnull(),'客户流量']
train.loc[train['前4天客户流量'].isnull(),'前4天客户流量']=train.loc[train['前4天客户流量'].isnull(),'客户流量']
train.loc[train['前5天客户流量'].isnull(),'前5天客户流量']=train.loc[train['前5天客户流量'].isnull(),'客户流量']
train.loc[train['前6天客户流量'].isnull(),'前6天客户流量']=train.loc[train['前6天客户流量'].isnull(),'客户流量']
train.loc[train['前7天客户流量'].isnull(),'前7天客户流量']=train.loc[train['前7天客户流量'].isnull(),'客户流量']
train.loc[train['前8天客户流量'].isnull(),'前8天客户流量']=train.loc[train['前8天客户流量'].isnull(),'客户流量']
train.loc[train['前9天客户流量'].isnull(),'前9天客户流量']=train.loc[train['前9天客户流量'].isnull(),'客户流量']
train.loc[train['前10天客户流量'].isnull(),'前10天客户流量']=train.loc[train['前10天客户流量'].isnull(),'客户流量']
train.loc[train['前11天客户流量'].isnull(),'前11天客户流量']=train.loc[train['前11天客户流量'].isnull(),'客户流量']
train.loc[train['前12天客户流量'].isnull(),'前12天客户流量']=train.loc[train['前12天客户流量'].isnull(),'客户流量']
train.loc[train['前13天客户流量'].isnull(),'前13天客户流量']=train.loc[train['前13天客户流量'].isnull(),'客户流量']
train.loc[train['前14天客户流量'].isnull(),'前14天客户流量']=train.loc[train['前14天客户流量'].isnull(),'客户流量']
train.loc[train['前15天客户流量'].isnull(),'前15天客户流量']=train.loc[train['前15天客户流量'].isnull(),'客户流量']
train.loc[train['前16天客户流量'].isnull(),'前16天客户流量']=train.loc[train['前16天客户流量'].isnull(),'客户流量']
train.loc[train['前17天客户流量'].isnull(),'前17天客户流量']=train.loc[train['前17天客户流量'].isnull(),'客户流量']
train.loc[train['前18天客户流量'].isnull(),'前18天客户流量']=train.loc[train['前18天客户流量'].isnull(),'客户流量']
train.loc[train['前19天客户流量'].isnull(),'前19天客户流量']=train.loc[train['前19天客户流量'].isnull(),'客户流量']
train.loc[train['前20天客户流量'].isnull(),'前20天客户流量']=train.loc[train['前20天客户流量'].isnull(),'客户流量']
train.loc[train['前21天客户流量'].isnull(),'前21天客户流量']=train.loc[train['前21天客户流量'].isnull(),'客户流量']
train.loc[train['前22天客户流量'].isnull(),'前22天客户流量']=train.loc[train['前22天客户流量'].isnull(),'客户流量']
train.loc[train['前23天客户流量'].isnull(),'前23天客户流量']=train.loc[train['前23天客户流量'].isnull(),'客户流量']
train.loc[train['前24天客户流量'].isnull(),'前24天客户流量']=train.loc[train['前24天客户流量'].isnull(),'客户流量']
train.loc[train['前25天客户流量'].isnull(),'前25天客户流量']=train.loc[train['前25天客户流量'].isnull(),'客户流量']
train.loc[train['前26天客户流量'].isnull(),'前26天客户流量']=train.loc[train['前26天客户流量'].isnull(),'客户流量']
train.loc[train['前27天客户流量'].isnull(),'前27天客户流量']=train.loc[train['前27天客户流量'].isnull(),'客户流量']
train.loc[train['前28天客户流量'].isnull(),'前28天客户流量']=train.loc[train['前28天客户流量'].isnull(),'客户流量']
train=train.fillna(method='bfill')

# %%
from sklearn.ensemble.forest import RandomForestRegressor
train_data=train[['客户流量','商家id', '所在位置编号', '人均消费', '评分', '评论数', '门店等级',
        '星期', '前1天客户流量', '前2天客户流量', '前3天客户流量',
       '前4天客户流量', '前5天客户流量', '前6天客户流量', '前7天客户流量', '前8天客户流量', '前9天客户流量',
       '前10天客户流量', '前11天客户流量', '前12天客户流量', '前13天客户流量', '前14天客户流量', '前15天客户流量', '前16天客户流量', '前17天客户流量',
       '前18天客户流量', '前19天客户流量', '前20天客户流量', '前21天客户流量', '前22天客户流量', '前23天客户流量',
       '前24天客户流量', '前25天客户流量', '前26天客户流量', '前27天客户流量', '前28天客户流量']]
train_data=train_data.as_matrix()
X=train_data[:,1:]
y=train_data[:,0]
rfr = RandomForestRegressor(n_estimators=60)
rfr.fit(X, y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=60, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
importance=pd.Series(rfr.feature_importances_,index=['商家id', '所在位置编号', '人均消费', '评分', '评论数', '门店等级',
        '星期', '前1天客户流量', '前2天客户流量', '前3天客户流量',
       '前4天客户流量', '前5天客户流量', '前6天客户流量', '前7天客户流量', '前8天客户流量', '前9天客户流量',
       '前10天客户流量', '前11天客户流量', '前12天客户流量', '前13天客户流量', '前14天客户流量', '前15天客户流量', '前16天客户流量', '前17天客户流量',
       '前18天客户流量', '前19天客户流量', '前20天客户流量', '前21天客户流量', '前22天客户流量', '前23天客户流量',
       '前24天客户流量', '前25天客户流量', '前26天客户流量', '前27天客户流量', '前28天客户流量'])
importance
# Out:
# 商家id        0.002173
# 所在位置编号      0.002085
# 人均消费        0.002212
# 评分          0.000654
# 评论数         0.001307
# 门店等级        0.000461
# 星期          0.007142
# 前1天客户流量     0.721622
# 前2天客户流量     0.003607
# 前3天客户流量     0.005731
# 前4天客户流量     0.003994
# 前5天客户流量     0.003583
# 前6天客户流量     0.005884
# 前7天客户流量     0.151135
# 前8天客户流量     0.005016
# 前9天客户流量     0.002432
# 前10天客户流量    0.001902
# 前11天客户流量    0.002155
# 前12天客户流量    0.002175
# 前13天客户流量    0.002959
# 前14天客户流量    0.016482
# 前15天客户流量    0.002706
# 前16天客户流量    0.002093
# 前17天客户流量    0.001695
# 前18天客户流量    0.002298
# 前19天客户流量    0.002404
# 前20天客户流量    0.003171
# 前21天客户流量    0.010437
# 前22天客户流量    0.002494
# 前23天客户流量    0.002158
# 前24天客户流量    0.001940
# 前25天客户流量    0.002136
# 前26天客户流量    0.002358
# 前27天客户流量    0.003002
# 前28天客户流量    0.016398
# dtype: float64

# %%
def predict_numofguest(pay_info,test,rfr,date):
    pay_info1=pay_info.rename(columns={'支付时间':'前1天','客户流量':'前1天客户流量'})
    pay_info2=pay_info.rename(columns={'支付时间':'前2天','客户流量':'前2天客户流量'})
    pay_info3=pay_info.rename(columns={'支付时间':'前3天','客户流量':'前3天客户流量'})
    pay_info4=pay_info.rename(columns={'支付时间':'前4天','客户流量':'前4天客户流量'})
    pay_info5=pay_info.rename(columns={'支付时间':'前5天','客户流量':'前5天客户流量'})
    pay_info6=pay_info.rename(columns={'支付时间':'前6天','客户流量':'前6天客户流量'})
    pay_info7=pay_info.rename(columns={'支付时间':'前7天','客户流量':'前7天客户流量'})
    pay_info8=pay_info.rename(columns={'支付时间':'前8天','客户流量':'前8天客户流量'})
    pay_info9=pay_info.rename(columns={'支付时间':'前9天','客户流量':'前9天客户流量'})
    pay_info10=pay_info.rename(columns={'支付时间':'前10天','客户流量':'前10天客户流量'})
    pay_info11=pay_info.rename(columns={'支付时间':'前11天','客户流量':'前11天客户流量'})
    pay_info12=pay_info.rename(columns={'支付时间':'前12天','客户流量':'前12天客户流量'})
    pay_info13=pay_info.rename(columns={'支付时间':'前13天','客户流量':'前13天客户流量'})
    pay_info14=pay_info.rename(columns={'支付时间':'前14天','客户流量':'前14天客户流量'})
    pay_info15=pay_info.rename(columns={'支付时间':'前15天','客户流量':'前15天客户流量'})
    pay_info16=pay_info.rename(columns={'支付时间':'前16天','客户流量':'前16天客户流量'})
    pay_info17=pay_info.rename(columns={'支付时间':'前17天','客户流量':'前17天客户流量'})
    pay_info18=pay_info.rename(columns={'支付时间':'前18天','客户流量':'前18天客户流量'})
    pay_info19=pay_info.rename(columns={'支付时间':'前19天','客户流量':'前19天客户流量'})
    pay_info20=pay_info.rename(columns={'支付时间':'前20天','客户流量':'前20天客户流量'})
    pay_info21=pay_info.rename(columns={'支付时间':'前21天','客户流量':'前21天客户流量'})
    pay_info22=pay_info.rename(columns={'支付时间':'前22天','客户流量':'前22天客户流量'})
    pay_info23=pay_info.rename(columns={'支付时间':'前23天','客户流量':'前23天客户流量'})
    pay_info24=pay_info.rename(columns={'支付时间':'前24天','客户流量':'前24天客户流量'})
    pay_info25=pay_info.rename(columns={'支付时间':'前25天','客户流量':'前25天客户流量'})
    pay_info26=pay_info.rename(columns={'支付时间':'前26天','客户流量':'前26天客户流量'})
    pay_info27=pay_info.rename(columns={'支付时间':'前27天','客户流量':'前27天客户流量'})
    pay_info28=pay_info.rename(columns={'支付时间':'前28天','客户流量':'前28天客户流量'})
    test['支付时间']=test['支付时间'].apply(str)
    testn=test[test.支付时间==date]
    testn=testn.merge(pay_info1,how='left',on=['商家id','前1天'])
    testn=testn.merge(pay_info2,how='left',on=['商家id','前2天'])
    testn=testn.merge(pay_info3,how='left',on=['商家id','前3天'])
    testn=testn.merge(pay_info4,how='left',on=['商家id','前4天'])
    testn=testn.merge(pay_info5,how='left',on=['商家id','前5天'])
    testn=testn.merge(pay_info6,how='left',on=['商家id','前6天'])
    testn=testn.merge(pay_info7,how='left',on=['商家id','前7天'])
    testn=testn.merge(pay_info8,how='left',on=['商家id','前8天'])
    testn=testn.merge(pay_info9,how='left',on=['商家id','前9天'])
    testn=testn.merge(pay_info10,how='left',on=['商家id','前10天'])
    testn=testn.merge(pay_info11,how='left',on=['商家id','前11天'])
    testn=testn.merge(pay_info12,how='left',on=['商家id','前12天'])
    testn=testn.merge(pay_info13,how='left',on=['商家id','前13天'])
    testn=testn.merge(pay_info14,how='left',on=['商家id','前14天'])
    testn=testn.merge(pay_info15,how='left',on=['商家id','前15天'])
    testn=testn.merge(pay_info16,how='left',on=['商家id','前16天'])
    testn=testn.merge(pay_info17,how='left',on=['商家id','前17天'])
    testn=testn.merge(pay_info18,how='left',on=['商家id','前18天'])
    testn=testn.merge(pay_info19,how='left',on=['商家id','前19天'])
    testn=testn.merge(pay_info20,how='left',on=['商家id','前20天'])
    testn=testn.merge(pay_info21,how='left',on=['商家id','前21天'])
    testn=testn.merge(pay_info22,how='left',on=['商家id','前22天'])
    testn=testn.merge(pay_info23,how='left',on=['商家id','前23天'])
    testn=testn.merge(pay_info24,how='left',on=['商家id','前24天'])
    testn=testn.merge(pay_info25,how='left',on=['商家id','前25天'])
    testn=testn.merge(pay_info26,how='left',on=['商家id','前26天'])
    testn=testn.merge(pay_info27,how='left',on=['商家id','前27天'])
    testn=testn.merge(pay_info28,how='left',on=['商家id','前28天'])
    testn.drop(['前1天','前2天','前3天','前4天','前5天','前6天','前7天','前8天','前9天','前10天','前11天','前12天','前13天','前14天','前15天','前16天','前17天','前18天','前19天','前20天','前21天','前22天','前23天','前24天','前25天','前26天','前27天','前28天'],axis=1,inplace=True)
    testn=testn.fillna(method='bfill')
    testn_data=testn[['客户流量','商家id', '所在位置编号', '人均消费', '评分', '评论数', '门店等级',
        '星期', '前1天客户流量', '前2天客户流量', '前3天客户流量',
       '前4天客户流量', '前5天客户流量', '前6天客户流量', '前7天客户流量', '前8天客户流量', '前9天客户流量',
       '前10天客户流量', '前11天客户流量', '前12天客户流量', '前13天客户流量', '前14天客户流量', '前15天客户流量', '前16天客户流量', '前17天客户流量',
       '前18天客户流量', '前19天客户流量', '前20天客户流量', '前21天客户流量', '前22天客户流量', '前23天客户流量',
       '前24天客户流量', '前25天客户流量', '前26天客户流量', '前27天客户流量', '前28天客户流量']]
    testn_data=testn_data.as_matrix()
    X=testn_data[:,1:]
    pren=rfr.predict(X)
    remerge=pd.DataFrame(testn['商家id'])
    remerge['支付时间']=date
    remerge['客户流量']=pren
    frames=[pay_info,remerge]
    pay_info=pd.concat(frames)
    return pay_info,pren

# %%
pay_info=train[['商家id','支付时间','客户流量']]
pay_info,pre1=predict_numofguest(pay_info,test,rfr,'2016-11-01')
pay_info,pre2=predict_numofguest(pay_info,test,rfr,'2016-11-02')
pay_info,pre3=predict_numofguest(pay_info,test,rfr,'2016-11-03')
pay_info,pre4=predict_numofguest(pay_info,test,rfr,'2016-11-04')
pay_info,pre5=predict_numofguest(pay_info,test,rfr,'2016-11-05')
pay_info,pre6=predict_numofguest(pay_info,test,rfr,'2016-11-06')
pay_info,pre7=predict_numofguest(pay_info,test,rfr,'2016-11-07')
pay_info,pre8=predict_numofguest(pay_info,test,rfr,'2016-11-08')
pay_info,pre9=predict_numofguest(pay_info,test,rfr,'2016-11-09')
pay_info,pre10=predict_numofguest(pay_info,test,rfr,'2016-11-10')
pay_info,pre11=predict_numofguest(pay_info,test,rfr,'2016-11-11')
pay_info,pre12=predict_numofguest(pay_info,test,rfr,'2016-11-12')
pay_info,pre13=predict_numofguest(pay_info,test,rfr,'2016-11-13')
pay_info,pre14=predict_numofguest(pay_info,test,rfr,'2016-11-14')
#pay_info.to_csv('C:\\Users\\fcn\\Desktop\\dataset\\dataset\\init_result.txt')
shop_info=pd.read_csv('C:\\Users\\fcn\\Desktop\\dataset\\dataset\\shop_info.txt',names=['商家id','市名','所在位置编号','人均消费','评分','评论数','门店等级','一级品类名称','二级分类名称','三级分类名称'])
result=pd.DataFrame(shop_info['商家id'])
result['1']=pre1
result['2']=pre2
result['3']=pre3
result['4']=pre4
result['5']=pre5
result['6']=pre6
result['7']=pre7
result['8']=pre8
result['9']=pre9
result['10']=pre10
result['11']=pre11
result['12']=pre12
result['13']=pre13
result['14']=pre14
result.to_csv('C:\\Users\\fcn\\Desktop\\dataset\\dataset\\prediction.csv',encoding='utf-8',header=False,index=False)
result
# Out:
#       商家id           1           2           3           4           5  \
# 0        1  219.566667  218.783333  216.300000  251.950000  237.000000
# 1        2   88.183333   91.616667   95.400000  124.016667  129.316667
# 2        3   82.833333   78.083333   89.366667  100.883333  109.916667
# 3        4  107.716667  113.516667  123.950000  153.950000  208.700000
# 4        5  211.066667  201.000000  197.783333  197.083333  231.816667
# 5        6   96.750000  115.400000  107.416667  115.283333  117.466667
# 6        7  119.700000  125.066667  133.750000  140.366667  158.233333
# 7        8   91.500000   76.333333   69.233333   64.316667   72.483333
# 8        9  208.966667  211.283333  234.233333  230.766667  242.600000
# 9       10  109.733333  106.083333   96.666667  107.633333  102.883333
# 10      11  104.883333  100.166667   93.366667   83.216667   78.683333
# 11      12   56.150000   61.616667   64.616667   76.050000   79.050000
# ...
