# %%
import pandas as pd
import numpy as np
import datetime
from datetime import date
merge_info=pd.read_csv('C:\\Users\\fcn\\Desktop\\dataset\\dataset\\merge_info.txt',encoding='gbk')
merge_info
# Out:
#         商家id        支付时间  客户流量  市名  所在位置编号  人均消费   评分   评论数  门店等级 一级品类名称  \
# 0          1  2015-10-10   188  湖州     885     8  4.0  12.0     2     美食
# 1          1  2015-10-11   272  湖州     885     8  4.0  12.0     2     美食
# 2          1  2015-10-12   257  湖州     885     8  4.0  12.0     2     美食
# 3          1  2015-10-13   239  湖州     885     8  4.0  12.0     2     美食
# 4          1  2015-10-14   277  湖州     885     8  4.0  12.0     2     美食
# 5          1  2015-10-15   227  湖州     885     8  4.0  12.0     2     美食
# 6          1  2015-10-16   242  湖州     885     8  4.0  12.0     2     美食
# 7          1  2015-10-17   293  湖州     885     8  4.0  12.0     2     美食
# 8          1  2015-10-18   291  湖州     885     8  4.0  12.0     2     美食
# 9          1  2015-10-19   256  湖州     885     8  4.0  12.0     2     美食
# 10         1  2015-10-20   262  湖州     885     8  4.0  12.0     2     美食
# 11         1  2015-10-21   271  湖州     885     8  4.0  12.0     2     美食
# ...

# %%
merge_info['支付时间']=merge_info['支付时间'].apply(pd.to_datetime)
merge_info['星期']=merge_info['支付时间'].apply(date.isoweekday)
merge_info
# Out:
#         商家id       支付时间  客户流量  市名  所在位置编号  人均消费   评分   评论数  门店等级 一级品类名称  \
# 0          1 2015-10-10   188  湖州     885     8  4.0  12.0     2     美食
# 1          1 2015-10-11   272  湖州     885     8  4.0  12.0     2     美食
# 2          1 2015-10-12   257  湖州     885     8  4.0  12.0     2     美食
# 3          1 2015-10-13   239  湖州     885     8  4.0  12.0     2     美食
# 4          1 2015-10-14   277  湖州     885     8  4.0  12.0     2     美食
# 5          1 2015-10-15   227  湖州     885     8  4.0  12.0     2     美食
# 6          1 2015-10-16   242  湖州     885     8  4.0  12.0     2     美食
# 7          1 2015-10-17   293  湖州     885     8  4.0  12.0     2     美食
# 8          1 2015-10-18   291  湖州     885     8  4.0  12.0     2     美食
# 9          1 2015-10-19   256  湖州     885     8  4.0  12.0     2     美食
# 10         1 2015-10-20   262  湖州     885     8  4.0  12.0     2     美食
# 11         1 2015-10-21   271  湖州     885     8  4.0  12.0     2     美食
# ...

# %%
merge_info['前1天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=1))
merge_info['前2天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=2))
merge_info['前3天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=3))
merge_info['前4天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=4))
merge_info['前5天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=5))
merge_info['前6天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=6))
merge_info['前7天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=7))
merge_info['前8天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=8))
merge_info['前9天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=9))
merge_info['前10天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=10))
merge_info['前11天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=11))
merge_info['前12天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=12))
merge_info['前13天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=13))
merge_info['前14天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=14))
merge_info['前15天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=15))
merge_info['前16天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=16))
merge_info['前17天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=17))
merge_info['前18天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=18))
merge_info['前19天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=19))
merge_info['前20天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=20))
merge_info['前21天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=21))
merge_info['前22天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=22))
merge_info['前23天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=23))
merge_info['前24天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=24))
merge_info['前25天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=25))
merge_info['前26天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=26))
merge_info['前27天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=27))
merge_info['前28天']=merge_info['支付时间'].apply(lambda x:x- datetime.timedelta(days=28))
merge_info
# Out:
#         商家id       支付时间  客户流量  市名  所在位置编号  人均消费   评分   评论数  门店等级 一级品类名称  \
# 0          1 2015-10-10   188  湖州     885     8  4.0  12.0     2     美食
# 1          1 2015-10-11   272  湖州     885     8  4.0  12.0     2     美食
# 2          1 2015-10-12   257  湖州     885     8  4.0  12.0     2     美食
# 3          1 2015-10-13   239  湖州     885     8  4.0  12.0     2     美食
# 4          1 2015-10-14   277  湖州     885     8  4.0  12.0     2     美食
# 5          1 2015-10-15   227  湖州     885     8  4.0  12.0     2     美食
# 6          1 2015-10-16   242  湖州     885     8  4.0  12.0     2     美食
# 7          1 2015-10-17   293  湖州     885     8  4.0  12.0     2     美食
# 8          1 2015-10-18   291  湖州     885     8  4.0  12.0     2     美食
# 9          1 2015-10-19   256  湖州     885     8  4.0  12.0     2     美食
# 10         1 2015-10-20   262  湖州     885     8  4.0  12.0     2     美食
# 11         1 2015-10-21   271  湖州     885     8  4.0  12.0     2     美食
# ...

# %%
pay_info=merge_info[['商家id','支付时间','客户流量']]
pay_info
# Out:
#         商家id       支付时间  客户流量
# 0          1 2015-10-10   188
# 1          1 2015-10-11   272
# 2          1 2015-10-12   257
# 3          1 2015-10-13   239
# 4          1 2015-10-14   277
# 5          1 2015-10-15   227
# 6          1 2015-10-16   242
# 7          1 2015-10-17   293
# 8          1 2015-10-18   291
# 9          1 2015-10-19   256
# 10         1 2015-10-20   262
# 11         1 2015-10-21   271
# 12         1 2015-10-22   260
# 13         1 2015-10-23   240
# 14         1 2015-10-24   291
# 15         1 2015-10-25   286
# 16         1 2015-10-26   264
# 17         1 2015-10-27   295
# 18         1 2015-10-28   310
# 19         1 2015-10-29   212
# 20         1 2015-10-30   331
# 21         1 2015-10-31   347
# 22         1 2015-11-01   381
# 23         1 2015-11-02   332
# 24         1 2015-11-03   404
# 25         1 2015-11-04   392
# 26         1 2015-11-05   496
# 27         1 2015-11-06   430
# 28         1 2015-11-07   351
# 29         1 2015-11-08   288
# ...

# %%
pay_info1=pay_info.rename(columns={'支付时间':'前1天','客户流量':'前1天客户流量'})
pay_info2=pay_info.rename(columns={'支付时间':'前2天','客户流量':'前2天客户流量'})
pay_info3=pay_info.rename(columns={'支付时间':'前3天','客户流量':'前3天客户流量'})
pay_info4=pay_info.rename(columns={'支付时间':'前4天','客户流量':'前4天客户流量'})
pay_info5=pay_info.rename(columns={'支付时间':'前5天','客户流量':'前5天客户流量'})
pay_info6=pay_info.rename(columns={'支付时间':'前6天','客户流量':'前6天客户流量'})
pay_info7=pay_info.rename(columns={'支付时间':'前7天','客户流量':'前7天客户流量'})
pay_info8=pay_info.rename(columns={'支付时间':'前8天','客户流量':'前8天客户流量'})
pay_info9=pay_info.rename(columns={'支付时间':'前9天','客户流量':'前9天客户流量'})
pay_info10=pay_info.rename(columns={'支付时间':'前10天','客户流量':'前10天客户流量'})
pay_info11=pay_info.rename(columns={'支付时间':'前11天','客户流量':'前11天客户流量'})
pay_info12=pay_info.rename(columns={'支付时间':'前12天','客户流量':'前12天客户流量'})
pay_info13=pay_info.rename(columns={'支付时间':'前13天','客户流量':'前13天客户流量'})
pay_info14=pay_info.rename(columns={'支付时间':'前14天','客户流量':'前14天客户流量'})
pay_info15=pay_info.rename(columns={'支付时间':'前15天','客户流量':'前15天客户流量'})
pay_info16=pay_info.rename(columns={'支付时间':'前16天','客户流量':'前16天客户流量'})
pay_info17=pay_info.rename(columns={'支付时间':'前17天','客户流量':'前17天客户流量'})
pay_info18=pay_info.rename(columns={'支付时间':'前18天','客户流量':'前18天客户流量'})
pay_info19=pay_info.rename(columns={'支付时间':'前19天','客户流量':'前19天客户流量'})
pay_info20=pay_info.rename(columns={'支付时间':'前20天','客户流量':'前20天客户流量'})
pay_info21=pay_info.rename(columns={'支付时间':'前21天','客户流量':'前21天客户流量'})
pay_info22=pay_info.rename(columns={'支付时间':'前22天','客户流量':'前22天客户流量'})
pay_info23=pay_info.rename(columns={'支付时间':'前23天','客户流量':'前23天客户流量'})
pay_info24=pay_info.rename(columns={'支付时间':'前24天','客户流量':'前24天客户流量'})
pay_info25=pay_info.rename(columns={'支付时间':'前25天','客户流量':'前25天客户流量'})
pay_info26=pay_info.rename(columns={'支付时间':'前26天','客户流量':'前26天客户流量'})
pay_info27=pay_info.rename(columns={'支付时间':'前27天','客户流量':'前27天客户流量'})
pay_info28=pay_info.rename(columns={'支付时间':'前28天','客户流量':'前28天客户流量'})

# %%
merge_info=merge_info.merge(pay_info1,how='left',on=['商家id','前1天'])
merge_info=merge_info.merge(pay_info2,how='left',on=['商家id','前2天'])
merge_info=merge_info.merge(pay_info3,how='left',on=['商家id','前3天'])
merge_info=merge_info.merge(pay_info4,how='left',on=['商家id','前4天'])
merge_info=merge_info.merge(pay_info5,how='left',on=['商家id','前5天'])
merge_info=merge_info.merge(pay_info6,how='left',on=['商家id','前6天'])
merge_info=merge_info.merge(pay_info7,how='left',on=['商家id','前7天'])
merge_info=merge_info.merge(pay_info8,how='left',on=['商家id','前8天'])
merge_info=merge_info.merge(pay_info9,how='left',on=['商家id','前9天'])
merge_info=merge_info.merge(pay_info10,how='left',on=['商家id','前10天'])
merge_info=merge_info.merge(pay_info11,how='left',on=['商家id','前11天'])
merge_info=merge_info.merge(pay_info12,how='left',on=['商家id','前12天'])
merge_info=merge_info.merge(pay_info13,how='left',on=['商家id','前13天'])
merge_info=merge_info.merge(pay_info14,how='left',on=['商家id','前14天'])
merge_info=merge_info.merge(pay_info15,how='left',on=['商家id','前15天'])
merge_info=merge_info.merge(pay_info16,how='left',on=['商家id','前16天'])
merge_info=merge_info.merge(pay_info17,how='left',on=['商家id','前17天'])
merge_info=merge_info.merge(pay_info18,how='left',on=['商家id','前18天'])
merge_info=merge_info.merge(pay_info19,how='left',on=['商家id','前19天'])
merge_info=merge_info.merge(pay_info20,how='left',on=['商家id','前20天'])
merge_info=merge_info.merge(pay_info21,how='left',on=['商家id','前21天'])
merge_info=merge_info.merge(pay_info22,how='left',on=['商家id','前22天'])
merge_info=merge_info.merge(pay_info23,how='left',on=['商家id','前23天'])
merge_info=merge_info.merge(pay_info24,how='left',on=['商家id','前24天'])
merge_info=merge_info.merge(pay_info25,how='left',on=['商家id','前25天'])
merge_info=merge_info.merge(pay_info26,how='left',on=['商家id','前26天'])
merge_info=merge_info.merge(pay_info27,how='left',on=['商家id','前27天'])
merge_info=merge_info.merge(pay_info28,how='left',on=['商家id','前28天'])
merge_info.columns
# Out:
# Index(['商家id', '支付时间', '客户流量', '市名', '所在位置编号', '人均消费', '评分', '评论数', '门店等级',
#        '一级品类名称', '二级分类名称', '三级分类名称', '星期', '前1天', '前2天', '前3天', '前4天', '前5天',
#        '前6天', '前7天', '前8天', '前9天', '前10天', '前11天', '前12天', '前13天', '前14天',
#        '前15天', '前16天', '前17天', '前18天', '前19天', '前20天', '前21天', '前22天', '前23天',
#        '前24天', '前25天', '前26天', '前27天', '前28天', '前1天客户流量', '前2天客户流量', '前3天客户流量',
#        '前4天客户流量', '前5天客户流量', '前6天客户流量', '前7天客户流量', '前8天客户流量', '前9天客户流量',
#        '前10天客户流量', '前11天客户流量', '前12天客户流量', '前13天客户流量', '前14天客户流量', '前15天客户流量',
#        '前16天客户流量', '前17天客户流量', '前18天客户流量', '前19天客户流量', '前20天客户流量', '前21天客户流量',
#        '前22天客户流量', '前23天客户流量', '前24天客户流量', '前25天客户流量', '前26天客户流量', '前27天客户流量',
#        '前28天客户流量'],
#       dtype='object')

# %%
merge_info.drop(['前1天','前2天','前3天','前4天','前5天','前6天','前7天','前8天','前9天','前10天','前11天','前12天','前13天','前14天','前15天','前16天','前17天','前18天','前19天','前20天','前21天','前22天','前23天','前24天','前25天','前26天','前27天','前28天'],axis=1,inplace=True)
merge_info.columns
# Out:
# Index(['商家id', '支付时间', '客户流量', '市名', '所在位置编号', '人均消费', '评分', '评论数', '门店等级',
#        '一级品类名称', '二级分类名称', '三级分类名称', '星期', '前1天客户流量', '前2天客户流量', '前3天客户流量',
#        '前4天客户流量', '前5天客户流量', '前6天客户流量', '前7天客户流量', '前8天客户流量', '前9天客户流量',
#        '前10天客户流量', '前11天客户流量', '前12天客户流量', '前13天客户流量', '前14天客户流量', '前15天客户流量',
#        '前16天客户流量', '前17天客户流量', '前18天客户流量', '前19天客户流量', '前20天客户流量', '前21天客户流量',
#        '前22天客户流量', '前23天客户流量', '前24天客户流量', '前25天客户流量', '前26天客户流量', '前27天客户流量',
#        '前28天客户流量'],
#       dtype='object')

# %%
merge_info.to_csv('C:\\Users\\fcn\\Desktop\\dataset\\dataset\\train.txt')
